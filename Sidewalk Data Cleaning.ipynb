# %%
import geopandas as gpd
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline

# %%
fp = "SeattleData/Sidewalks/Sidewalks.shp"

# %%
sidewalk_data = gpd.read_file(fp)

# %%
sidewalk_data
# Out:
#        OBJECTID  COMPKEY  COMPTYPE  SEGKEY     UNITID UNITTYPE  \
# 0             1   666487        97   14933  SDW-46310      SDW
# 1             2   666491        97    9436  SDW-46311      SDW
# 2             3   666501        97   10355  SDW-46312      SDW
# 3             4   666567        97    9442  SDW-46314      SDW
# 4             5   666569        97    9442  SDW-46315      SDW
# ...         ...      ...       ...     ...        ...      ...
# 46189     46251   326888        97   21930  SDW-45274      SDW
# 46190     46252   327135        97   21722  SDW-33406      SDW
# 46191     46253   332901        97   15204  SDW-36509      SDW
# 46192     46254   332646        97   15129  SDW-45222      SDW
# 46193     46255   330037        97   16284  SDW-32053      SDW
#
#                                                 UNITDESC         ADDBY  \
# 0      E YESLER WAY BETWEEN BROADWAY AND 10TH AVE, N ...       FEGLEYC
# ...

# %%
sidewalk_data.explore()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/anaconda3/lib/python3.7/site-packages/folium/folium.py in _repr_html_(self, **kwargs)
#     297             self._parent = None
#     298         else:
# --> 299             out = self._parent._repr_html_(**kwargs)
#     300         return out
#     301
#
# /opt/anaconda3/lib/python3.7/site-packages/branca/element.py in _repr_html_(self, **kwargs)
#     324     def _repr_html_(self, **kwargs):
#     325         """Displays the Figure in a Jupyter notebook."""
# --> 326         html = escape(self.render(**kwargs))
# ...

# %%
fp = "SeattleData/Sidewalks.geojson"
data = gpd.read_file(fp)

# %%
data
# Out:
#        OBJECTID  COMPKEY  COMPTYPE  SEGKEY     UNITID UNITTYPE  \
# 0             1   666487        97   14933  SDW-46310      SDW
# 1             2   666491        97    9436  SDW-46311      SDW
# 2             3   666501        97   10355  SDW-46312      SDW
# 3             4   666567        97    9442  SDW-46314      SDW
# 4             5   666569        97    9442  SDW-46315      SDW
# ...         ...      ...       ...     ...        ...      ...
# 46189     46251   326888        97   21930  SDW-45274      SDW
# 46190     46252   327135        97   21722  SDW-33406      SDW
# 46191     46253   332901        97   15204  SDW-36509      SDW
# 46192     46254   332646        97   15129  SDW-45222      SDW
# 46193     46255   330037        97   16284  SDW-32053      SDW
#
#                                                 UNITDESC         ADDBY  \
# 0      E YESLER WAY BETWEEN BROADWAY AND 10TH AVE, N ...       FEGLEYC
# ...

# %%
data.dropna(subset=['geometry'])
# Out:
#        OBJECTID  COMPKEY  COMPTYPE  SEGKEY     UNITID UNITTYPE  \
# 0             1   666487        97   14933  SDW-46310      SDW
# 1             2   666491        97    9436  SDW-46311      SDW
# 2             3   666501        97   10355  SDW-46312      SDW
# 3             4   666567        97    9442  SDW-46314      SDW
# 4             5   666569        97    9442  SDW-46315      SDW
# ...         ...      ...       ...     ...        ...      ...
# 46189     46251   326888        97   21930  SDW-45274      SDW
# 46190     46252   327135        97   21722  SDW-33406      SDW
# 46191     46253   332901        97   15204  SDW-36509      SDW
# 46192     46254   332646        97   15129  SDW-45222      SDW
# 46193     46255   330037        97   16284  SDW-32053      SDW
#
#                                                 UNITDESC         ADDBY  \
# 0      E YESLER WAY BETWEEN BROADWAY AND 10TH AVE, N ...       FEGLEYC
# ...

# %%
data.plot()

# %%
data.loc[data['SHAPE_Length'] == 0]
# Out:
#        OBJECTID  COMPKEY  COMPTYPE  SEGKEY     UNITID UNITTYPE  \
# 1083       1084   333730        97   20386  SDW-36056      SDW
# 1564       1565   333863        97    2891  SDW-37761      SDW
# 1687       1688   673708        97  673443  SDW-46612      SDW
# 1752       1754   673178        97   19432  SDW-46605      SDW
# 2080       2083   294969        97   12876   SDW-5669      SDW
# ...         ...      ...       ...     ...        ...      ...
# 45152     45161   328638        97   12281  SDW-44461      SDW
# 45153     45162   328639        97   12281  SDW-30460      SDW
# 45292     45301   328809        97   12237  SDW-33080      SDW
# 45521     45530   329885        97   12454  SDW-32974      SDW
# 45769     45778   330246        97   18281  SDW-44690      SDW
#
#                                                 UNITDESC         ADDBY  \
# 1083   S HORTON ST BETWEEN 6TH AVE S AND 8TH AVE S, S...  SW DATA LOAD
# ...

# %%
data.drop(data.index[data['SHAPE_Length'] == 0], inplace=True)

# %%
data
# Out:
#        OBJECTID  COMPKEY  COMPTYPE  SEGKEY     UNITID UNITTYPE  \
# 0             1   666487        97   14933  SDW-46310      SDW
# 1             2   666491        97    9436  SDW-46311      SDW
# 2             3   666501        97   10355  SDW-46312      SDW
# 3             4   666567        97    9442  SDW-46314      SDW
# 4             5   666569        97    9442  SDW-46315      SDW
# ...         ...      ...       ...     ...        ...      ...
# 46189     46251   326888        97   21930  SDW-45274      SDW
# 46190     46252   327135        97   21722  SDW-33406      SDW
# 46191     46253   332901        97   15204  SDW-36509      SDW
# 46192     46254   332646        97   15129  SDW-45222      SDW
# 46193     46255   330037        97   16284  SDW-32053      SDW
#
#                                                 UNITDESC         ADDBY  \
# 0      E YESLER WAY BETWEEN BROADWAY AND 10TH AVE, N ...       FEGLEYC
# ...

# %%
data.to_file("SidewalksClean.shp")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   """Entry point for launching an IPython kernel.
